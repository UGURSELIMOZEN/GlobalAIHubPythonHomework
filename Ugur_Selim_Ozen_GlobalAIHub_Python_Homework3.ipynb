# %% [markdown]
# # HOMEWORK 1
#
#  - You are free on this assignment.
#  - You can set the rules yourself.There is only two things expected from you.
#  - When entering the game , The User's name  for example "Welcome LeBron" should be pressed on the screen.
#  - When the game is over , exit the game . So let the game ended.

# %%
last_right = 3
rights = 6
number_of_founded_letters = 0
guessed_failed_letters = []
guessed_founded_letters = []
Word_categories = ['Animals' , 'Colors' , 'Car_Brands' , 'Countries' , 'Fruits']
Animals = ['dog','cat','bear','snake','cow']
Colors = ['blue','white','black','yellow','pink']
CarBrands = ['ford','opel','mercedes','renault','audi']
Countries = ['turkey','germany','china','india','brasil']
Fruits = ['apple','mandarin','cherry','pear','banana']

User_name = input('Please enter your name : ')
print('\nWelcome {} to the Hangman Game '.format(User_name))
print("\nThese are the game rules !\n\nFirstly,You need to select one Word_category.\n\
You will get randomly one word according to your word_category.\nAfter that,you will select the index of your word randomly.\n\
You will have the right to say 6 wrong letters.\n\
If your mistakes exceed 6 years, the game is over.\n\
\n\n\nNow,Lets begin the game !")

print("\nThese are the word categories and select one of them !\n\nEnter 1 for Animals\n\
Enter 2 for Colors\nEnter 3 for CarBrands\nEnter 4 for Countries\nEnter 5 for Fruits")

word_category_input = int(input('\nYour word category selection is : '))
if word_category_input == 1 :
        print('\nOkey, you selected Animals.')
        Animal_word_index = int(input('\nNow ,Please select your index for random word from the following numbers  , 0-1-2-3-4  :  '))
        for item in range(15):
                letter_prediction = input('Enter the letter you guessed :')
                if (letter_prediction in Animals[Animal_word_index]) and not(letter_prediction in guessed_founded_letters) :
                    guessed_founded_letters.append(letter_prediction)
                    print('You found one letter of word  , one of them is {}'.format(letter_prediction))
                    number_of_founded_letters +=1
                    if len(Animals[Animal_word_index]) == number_of_founded_letters :
                        print('\nWell done to you ! You have founded all the letters of the word , They are :{}'.format(guessed_founded_letters))
                        for i in range(3):
                            last_prediction = input('\nPlease enter your combined predicted word with this letters , you have {} rights :'.format(last_right))
                            if last_prediction == Animals[Animal_word_index] :
                                print('Congratulations ! You founded the word and won the game , the word is :{}'.format(last_prediction))
                                break
                            else :
                                last_right = last_right-1
                                print('You failed ! , {} rights left'.format(last_right))
                                if last_right == 0 :
                                    print('0 rights left ,Game is Over !')
                                    break
                        break
                    
                   
                elif (letter_prediction in guessed_founded_letters) :
                        print('You already founded the {} letter , try another !'.format(letter_prediction))
                        
                elif (letter_prediction in guessed_failed_letters) == False  :
                        guessed_failed_letters.append(letter_prediction)
                        rights = rights-1
                        print('You failed  ,{} rights of you left'.format(rights) ,'\n')
                        if rights == 0 :
                            print('0 rights left ,Game is Over !')
                            break
                else :
                        print('You already entered this letter  ,try another !')
            
                
                
                
elif word_category_input == 2 :
        print('\nOkey, you selected Animals.')
        Color_word_index = int(input('\nNow ,Please select your index for random word from the following numbers  , 0-1-2-3-4  :  '))
        for item in range(15):
                letter_prediction = input('Enter the letter you guessed :')
                if (letter_prediction in Colors[Color_word_index]) and not(letter_prediction in guessed_founded_letters) :
                    guessed_founded_letters.append(letter_prediction)
                    print('You found one letter of word  , one of them is {}'.format(letter_prediction))
                    number_of_founded_letters +=1
                    if len(Colors[Color_word_index]) == number_of_founded_letters :
                        print('\nWell done to you ! You have founded all the letters of the word , They are :{}'.format(guessed_founded_letters))
                        for i in range(3):
                            last_prediction = input('\nPlease enter your combined predicted word with this letters , you have {} rights :'.format(last_right))
                            if last_prediction == Colors[Color_word_index] :
                                print('Congratulations ! You founded the word and won the game , the word is :{}'.format(last_prediction))
                                break
                            else :
                                last_right = last_right-1
                                print('You failed ! , {} rights left'.format(last_right))
                                if last_right == 0 :
                                    print('0 rights left ,Game is Over !')
                                    break
                        break
                    
                   
                elif (letter_prediction in guessed_founded_letters) :
                        print('You already founded the {} letter , try another !'.format(letter_prediction))
                        
                elif (letter_prediction in guessed_failed_letters) == False  :
                        guessed_failed_letters.append(letter_prediction)
                        rights = rights-1
                        print('You failed  ,{} rights of you left'.format(rights) ,'\n')
                        if rights == 0 :
                            print('0 rights left ,Game is Over !')
                            break
                else :
                        print('You already entered this letter  ,try another !')
            
elif word_category_input == 3 :
        print('\nOkey, you selected Animals.')
        CarBrands_word_index = int(input('\nNow ,Please select your index for random word from the following numbers  , 0-1-2-3-4  :  '))
        for item in range(15):
                letter_prediction = input('Enter the letter you guessed :')
                if (letter_prediction in CarBrands[CarBrands_word_index]) and not(letter_prediction in guessed_founded_letters) :
                    guessed_founded_letters.append(letter_prediction)
                    print('You found one letter of word  , one of them is {}'.format(letter_prediction))
                    number_of_founded_letters +=1
                    if len(CarBrands[CarBrands_word_index]) == number_of_founded_letters :
                        print('\nWell done to you ! You have founded all the letters of the word , They are :{}'.format(guessed_founded_letters))
                        for i in range(3):
                            last_prediction = input('\nPlease enter your combined predicted word with this letters , you have {} rights :'.format(last_right))
                            if last_prediction == CarBrands[CarBrands_word_index] :
                                print('Congratulations ! You founded the word and won the game , the word is :{}'.format(last_prediction))
                                break
                            else :
                                last_right = last_right-1
                                print('You failed ! , {} rights left'.format(last_right))
                                if last_right == 0 :
                                    print('0 rights left ,Game is Over !')
                                    break
                        break
                    
                   
                elif (letter_prediction in guessed_founded_letters) :
                        print('You already founded the {} letter , try another !'.format(letter_prediction))
                        
                elif (letter_prediction in guessed_failed_letters) == False  :
                        guessed_failed_letters.append(letter_prediction)
                        rights = rights-1
                        print('You failed  ,{} rights of you left'.format(rights) ,'\n')
                        if rights == 0 :
                            print('0 rights left ,Game is Over !')
                            break
                else :
                        print('You already entered this letter  ,try another !')
            
elif word_category_input == 4 :
        print('\nOkey, you selected Animals.')
        Country_word_index = int(input('\nNow ,Please select your index for random word from the following numbers  , 0-1-2-3-4  :  '))
        for item in range(15):
                letter_prediction = input('Enter the letter you guessed :')
                if (letter_prediction in Countries[Country_word_index]) and not(letter_prediction in guessed_founded_letters) :
                    guessed_founded_letters.append(letter_prediction)
                    print('You found one letter of word  , one of them is {}'.format(letter_prediction))
                    number_of_founded_letters +=1
                    if len(Countries[Country_word_index]) == number_of_founded_letters :
                        print('\nWell done to you ! You have founded all the letters of the word , They are :{}'.format(guessed_founded_letters))
                        for i in range(3):
                            last_prediction = input('\nPlease enter your combined predicted word with this letters , you have {} rights :'.format(last_right))
                            if last_prediction == Countries[Country_word_index] :
                                print('Congratulations ! You founded the word and won the game , the word is :{}'.format(last_prediction))
                                break
                            else :
                                last_right = last_right-1
                                print('You failed ! , {} rights left'.format(last_right))
                                if last_right == 0 :
                                    print('0 rights left ,Game is Over !')
                                    break
                        break
                    
                   
                elif (letter_prediction in guessed_founded_letters) :
                        print('You already founded the {} letter , try another !'.format(letter_prediction))
                        
                elif (letter_prediction in guessed_failed_letters) == False  :
                        guessed_failed_letters.append(letter_prediction)
                        rights = rights-1
                        print('You failed  ,{} rights of you left'.format(rights) ,'\n')
                        if rights == 0 :
                            print('0 rights left ,Game is Over !')
                            break
                else :
                        print('You already entered this letter  ,try another !')
            
elif word_category_input == 5 :
        print('\nOkey, you selected Animals.')
        Fruit_word_index = int(input('\nNow ,Please select your index for random word from the following numbers  , 0-1-2-3-4  :  '))
        for item in range(15):
                letter_prediction = input('Enter the letter you guessed :')
                if (letter_prediction in Fruits[Fruit_word_index]) and not(letter_prediction in guessed_founded_letters) :
                    guessed_founded_letters.append(letter_prediction)
                    print('You found one letter of word  , one of them is {}'.format(letter_prediction))
                    number_of_founded_letters +=1
                    if len(Fruits[Fruit_word_index]) == number_of_founded_letters :
                        print('\nWell done to you ! You have founded all the letters of the word , They are :{}'.format(guessed_founded_letters))
                        for i in range(3):
                            last_prediction = input('\nPlease enter your combined predicted word with this letters , you have {} rights :'.format(last_right))
                            if last_prediction == Fruits[Fruit_word_index] :
                                print('Congratulations ! You founded the word and won the game , the word is :{}'.format(last_prediction))
                                break
                            else :
                                last_right = last_right-1
                                print('You failed ! , {} rights left'.format(last_right))
                                if last_right == 0 :
                                    print('0 rights left ,Game is Over !')
                                    break
                        break
                    
                   
                elif (letter_prediction in guessed_founded_letters) :
                        print('You already founded the {} letter , try another !'.format(letter_prediction))
                        
                elif (letter_prediction in guessed_failed_letters) == False  :
                        guessed_failed_letters.append(letter_prediction)
                        rights = rights-1
                        print('You failed  ,{} rights of you left'.format(rights) ,'\n')
                        if rights == 0 :
                            print('0 rights left ,Game is Over !')
                            break
                else :
                        print('You already entered this letter  ,try another !')
# Out:
# Please enter your name : John
#
# Welcome John to the Hangman Game
#
# These are the game rules !
#
# Firstly,You need to select one Word_category.
# You will get randomly one word according to your word_category.
# After that,you will select the index of your word randomly.
# You will have the right to say 6 wrong letters.
# If your mistakes exceed 6 years, the game is over.
#
#
#
# Now,Lets begin the game !
#
# These are the word categories and select one of them !
#
# Enter 1 for Animals
# Enter 2 for Colors
# Enter 3 for CarBrands
# Enter 4 for Countries
# Enter 5 for Fruits
#
# Your word category selection is : 4
#
# Okey, you selected Animals.
#
# Now ,Please select your index for random word from the following numbers  , 0-1-2-3-4  :  0
# Enter the letter you guessed :g
# You failed  ,5 rights of you left
#
# Enter the letter you guessed :t
# You found one letter of word  , one of them is t
# Enter the letter you guessed :u
# You found one letter of word  , one of them is u
# ...
